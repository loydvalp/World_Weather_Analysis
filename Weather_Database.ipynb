# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random 
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 12.5 µs ± 255 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500. 
# %timeit latitudes(1500)
# Out:
# 1.72 ms ± 186 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=84bf783b0426ae0eabcc200e14cbdb41

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 597

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# List of city data
city_data = []

#Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        pass
    
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0 
        pass
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

 #Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Convert the array of dictionaries to a Pandas DataFrame.
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | oktyabrskiy
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | cilegon
# Processing Record 5 of Set 1 | carutapera
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | zhanaozen
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | tual
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | eydhafushi
# Processing Record 15 of Set 1 | namanga
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | baijiantan
# Processing Record 18 of Set 1 | mitsamiouli
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | leshukonskoye
# Processing Record 21 of Set 1 | palmer
# Processing Record 22 of Set 1 | jumla
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | leningradskiy
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | bend
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | asfi
# Processing Record 32 of Set 1 | rovaniemi
# Processing Record 33 of Set 1 | faanui
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | antalaha
# Processing Record 36 of Set 1 | sola
# Processing Record 37 of Set 1 | nanortalik
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | aykhal
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | verkhoyansk
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | port hawkesbury
# Processing Record 49 of Set 1 | isangel
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | namibe
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | dingle
# Processing Record 4 of Set 2 | yulara
# Processing Record 5 of Set 2 | altus
# Processing Record 6 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | port keats
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | hofn
# Processing Record 12 of Set 2 | altamont
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | caruray
# Processing Record 15 of Set 2 | mahibadhoo
# Processing Record 16 of Set 2 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | erzin
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | calvinia
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | menongue
# Processing Record 27 of Set 2 | ankang
# Processing Record 28 of Set 2 | zonguldak
# Processing Record 29 of Set 2 | caravelas
# Processing Record 30 of Set 2 | heze
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | datong
# Processing Record 33 of Set 2 | naco
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | maceio
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | nome
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | santa rosalia
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | adrar
# Processing Record 45 of Set 2 | griffith
# Processing Record 46 of Set 2 | yago
# Processing Record 47 of Set 2 | komsomolskiy
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | mattru
# Processing Record 1 of Set 3 | ketchikan
# Processing Record 2 of Set 3 | milkovo
# Processing Record 3 of Set 3 | taybad
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | banff
# Processing Record 6 of Set 3 | san jose del guaviare
# Processing Record 7 of Set 3 | belaya gora
# Processing Record 8 of Set 3 | ust-nera
# Processing Record 9 of Set 3 | waingapu
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | tautira
# Processing Record 13 of Set 3 | angoche
# Processing Record 14 of Set 3 | luanda
# Processing Record 15 of Set 3 | aripuana
# Processing Record 16 of Set 3 | malinovoye ozero
# Processing Record 17 of Set 3 | great falls
# Processing Record 18 of Set 3 | lichinga
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 3 | sabha
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | tiznit
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | turukhansk
# Processing Record 28 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | sakakah
# Processing Record 32 of Set 3 | ruwi
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | asau
# Processing Record 35 of Set 3 | tulun
# Processing Record 36 of Set 3 | orje
# Processing Record 37 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 3 | churapcha
# Processing Record 39 of Set 3 | ucluelet
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | blackwater
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | poltavka
# Processing Record 45 of Set 3 | thunder bay
# Processing Record 46 of Set 3 | vila franca do campo
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | ambon
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | beringovskiy
# Processing Record 2 of Set 4 | labuhan
# Processing Record 3 of Set 4 | richards bay
# Processing Record 4 of Set 4 | darnah
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | robat karim
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | lingao
# Processing Record 9 of Set 4 | ketchenery
# City not found. Skipping...
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | maniitsoq
# Processing Record 12 of Set 4 | mbour
# Processing Record 13 of Set 4 | naze
# Processing Record 14 of Set 4 | oksovskiy
# Processing Record 15 of Set 4 | turinsk
# Processing Record 16 of Set 4 | castanheira de pera
# Processing Record 17 of Set 4 | byron bay
# Processing Record 18 of Set 4 | asosa
# Processing Record 19 of Set 4 | broken hill
# Processing Record 20 of Set 4 | laguna
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | bose
# Processing Record 23 of Set 4 | kupang
# Processing Record 24 of Set 4 | yumen
# Processing Record 25 of Set 4 | marsh harbour
# Processing Record 26 of Set 4 | shingu
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | tuatapere
# Processing Record 31 of Set 4 | cascais
# Processing Record 32 of Set 4 | meghraj
# Processing Record 33 of Set 4 | erdenet
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | inuvik
# Processing Record 36 of Set 4 | klyuchi
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | north bend
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | yavatmal
# Processing Record 42 of Set 4 | damaturu
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | koboldo
# City not found. Skipping...
# Processing Record 45 of Set 4 | pochutla
# Processing Record 46 of Set 4 | sansai
# City not found. Skipping...
# Processing Record 47 of Set 4 | fergus falls
# Processing Record 48 of Set 4 | manta
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | lufilufi
# Processing Record 3 of Set 5 | nokha
# Processing Record 4 of Set 5 | zhigansk
# Processing Record 5 of Set 5 | hudson bay
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | kirovskiy
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | qiongshan
# Processing Record 11 of Set 5 | condado
# Processing Record 12 of Set 5 | san carlos de bariloche
# Processing Record 13 of Set 5 | saint marys
# Processing Record 14 of Set 5 | kilindoni
# Processing Record 15 of Set 5 | salalah
# Processing Record 16 of Set 5 | teremia mare
# Processing Record 17 of Set 5 | ngunguru
# Processing Record 18 of Set 5 | iqaluit
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 5 | camocim
# Processing Record 23 of Set 5 | taquarituba
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | cabo san lucas
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | kalmunai
# Processing Record 28 of Set 5 | lebu
# Processing Record 29 of Set 5 | grindavik
# Processing Record 30 of Set 5 | ahipara
# Processing Record 31 of Set 5 | opuwo
# Processing Record 32 of Set 5 | kuytun
# Processing Record 33 of Set 5 | fortuna
# Processing Record 34 of Set 5 | san joaquin
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | kavaratti
# Processing Record 37 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 5 | bonavista
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | quatre cocos
# Processing Record 42 of Set 5 | elbrus
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 5 | tabou
# Processing Record 47 of Set 5 | kathmandu
# Processing Record 48 of Set 5 | bulgan
# Processing Record 49 of Set 5 | soyo
# Processing Record 50 of Set 5 | port elizabeth
# Processing Record 1 of Set 6 | chimoio
# Processing Record 2 of Set 6 | poli
# Processing Record 3 of Set 6 | koumac
# Processing Record 4 of Set 6 | laurel
# Processing Record 5 of Set 6 | bud
# Processing Record 6 of Set 6 | zhangye
# Processing Record 7 of Set 6 | gizo
# Processing Record 8 of Set 6 | provideniya
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | portobelo
# Processing Record 12 of Set 6 | lovozero
# Processing Record 13 of Set 6 | kendari
# Processing Record 14 of Set 6 | biloela
# Processing Record 15 of Set 6 | karratha
# Processing Record 16 of Set 6 | lagoa vermelha
# Processing Record 17 of Set 6 | nancha
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | yining
# Processing Record 20 of Set 6 | visby
# Processing Record 21 of Set 6 | columbia
# Processing Record 22 of Set 6 | blackfoot
# Processing Record 23 of Set 6 | grand-santi
# Processing Record 24 of Set 6 | kloulklubed
# Processing Record 25 of Set 6 | raga
# Processing Record 26 of Set 6 | ixtapa
# Processing Record 27 of Set 6 | asyut
# Processing Record 28 of Set 6 | havre-saint-pierre
# Processing Record 29 of Set 6 | altay
# Processing Record 30 of Set 6 | ossora
# Processing Record 31 of Set 6 | lipin bor
# Processing Record 32 of Set 6 | cap malheureux
# Processing Record 33 of Set 6 | nouadhibou
# Processing Record 34 of Set 6 | aksarka
# Processing Record 35 of Set 6 | la rioja
# Processing Record 36 of Set 6 | svetlaya
# Processing Record 37 of Set 6 | davila
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 6 | bambanglipuro
# Processing Record 41 of Set 6 | edd
# Processing Record 42 of Set 6 | dunedin
# Processing Record 43 of Set 6 | illapel
# Processing Record 44 of Set 6 | saint-georges
# Processing Record 45 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 6 | bay city
# Processing Record 47 of Set 6 | zavitinsk
# Processing Record 48 of Set 6 | lata
# Processing Record 49 of Set 6 | pevek
# Processing Record 50 of Set 6 | copiapo
# Processing Record 1 of Set 7 | chokurdakh
# Processing Record 2 of Set 7 | am timan
# Processing Record 3 of Set 7 | mao
# Processing Record 4 of Set 7 | selizharovo
# Processing Record 5 of Set 7 | la plata
# Processing Record 6 of Set 7 | nicoya
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | ashington
# Processing Record 9 of Set 7 | biscarrosse
# Processing Record 10 of Set 7 | tabuk
# Processing Record 11 of Set 7 | longyearbyen
# Processing Record 12 of Set 7 | port hardy
# Processing Record 13 of Set 7 | buchanan
# Processing Record 14 of Set 7 | daru
# Processing Record 15 of Set 7 | champerico
# Processing Record 16 of Set 7 | kurchum
# Processing Record 17 of Set 7 | poum
# Processing Record 18 of Set 7 | takoradi
# Processing Record 19 of Set 7 | huilong
# Processing Record 20 of Set 7 | scarborough
# Processing Record 21 of Set 7 | nemuro
# Processing Record 22 of Set 7 | kapasan
# Processing Record 23 of Set 7 | broome
# Processing Record 24 of Set 7 | samarai
# Processing Record 25 of Set 7 | puri
# Processing Record 26 of Set 7 | airai
# Processing Record 27 of Set 7 | victor harbor
# Processing Record 28 of Set 7 | pakxan
# Processing Record 29 of Set 7 | puerto maldonado
# Processing Record 30 of Set 7 | walvis bay
# Processing Record 31 of Set 7 | katsuura
# Processing Record 32 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 7 | mildura
# Processing Record 34 of Set 7 | dudinka
# Processing Record 35 of Set 7 | roma
# Processing Record 36 of Set 7 | hommelvik
# Processing Record 37 of Set 7 | abnub
# Processing Record 38 of Set 7 | atasu
# Processing Record 39 of Set 7 | karangasem
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | bryan
# Processing Record 42 of Set 7 | rafai
# Processing Record 43 of Set 7 | isla vista
# Processing Record 44 of Set 7 | makakilo city
# Processing Record 45 of Set 7 | narsaq
# Processing Record 46 of Set 7 | mitzic
# Processing Record 47 of Set 7 | redlands
# Processing Record 48 of Set 7 | coquimbo
# Processing Record 49 of Set 7 | gat
# Processing Record 50 of Set 7 | hamilton
# Processing Record 1 of Set 8 | kolondieba
# Processing Record 2 of Set 8 | zaraza
# Processing Record 3 of Set 8 | villa del rosario
# Processing Record 4 of Set 8 | morden
# Processing Record 5 of Set 8 | marsabit
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | solina
# Processing Record 8 of Set 8 | xunchang
# Processing Record 9 of Set 8 | brawley
# Processing Record 10 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 11 of Set 8 | asekeyevo
# Processing Record 12 of Set 8 | cullinan
# Processing Record 13 of Set 8 | nkoteng
# Processing Record 14 of Set 8 | treinta y tres
# Processing Record 15 of Set 8 | mount gambier
# Processing Record 16 of Set 8 | holme
# Processing Record 17 of Set 8 | bolshoye selo
# Processing Record 18 of Set 8 | tasiilaq
# Processing Record 19 of Set 8 | castries
# Processing Record 20 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 8 | tuskegee
# Processing Record 22 of Set 8 | killybegs
# Processing Record 23 of Set 8 | magadan
# Processing Record 24 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 8 | tazovskiy
# Processing Record 26 of Set 8 | guerrero negro
# Processing Record 27 of Set 8 | reinosa
# Processing Record 28 of Set 8 | zheleznodorozhnyy
# Processing Record 29 of Set 8 | agsu
# City not found. Skipping...
# Processing Record 30 of Set 8 | sayanskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | chaykovskaya
# Processing Record 32 of Set 8 | formosa
# Processing Record 33 of Set 8 | kembe
# Processing Record 34 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 8 | fez
# Processing Record 36 of Set 8 | maine-soroa
# Processing Record 37 of Set 8 | khair
# Processing Record 38 of Set 8 | selma
# Processing Record 39 of Set 8 | ambilobe
# Processing Record 40 of Set 8 | canico
# Processing Record 41 of Set 8 | sawtell
# Processing Record 42 of Set 8 | pingliang
# Processing Record 43 of Set 8 | east london
# Processing Record 44 of Set 8 | alta floresta
# Processing Record 45 of Set 8 | ancud
# Processing Record 46 of Set 8 | constitucion
# Processing Record 47 of Set 8 | olinda
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | fort nelson
# Processing Record 50 of Set 8 | yar-sale
# Processing Record 1 of Set 9 | obo
# Processing Record 2 of Set 9 | alexandria
# Processing Record 3 of Set 9 | mocuba
# Processing Record 4 of Set 9 | alofi
# Processing Record 5 of Set 9 | mahenge
# Processing Record 6 of Set 9 | melbu
# Processing Record 7 of Set 9 | buraydah
# Processing Record 8 of Set 9 | hire
# City not found. Skipping...
# Processing Record 9 of Set 9 | port macquarie
# Processing Record 10 of Set 9 | romny
# Processing Record 11 of Set 9 | son la
# Processing Record 12 of Set 9 | ilulissat
# Processing Record 13 of Set 9 | krasnoselkup
# Processing Record 14 of Set 9 | puerto escondido
# Processing Record 15 of Set 9 | lagos
# Processing Record 16 of Set 9 | hobyo
# Processing Record 17 of Set 9 | guatire
# Processing Record 18 of Set 9 | tamiahua
# Processing Record 19 of Set 9 | podporozhye
# Processing Record 20 of Set 9 | paamiut
# Processing Record 21 of Set 9 | fort frances
# Processing Record 22 of Set 9 | san juan de los morros
# Processing Record 23 of Set 9 | dataganj
# Processing Record 24 of Set 9 | fairbanks
# Processing Record 25 of Set 9 | bawku
# Processing Record 26 of Set 9 | gangawati
# Processing Record 27 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 9 | rawson
# Processing Record 29 of Set 9 | sonoita
# Processing Record 30 of Set 9 | namatanai
# Processing Record 31 of Set 9 | barguzin
# Processing Record 32 of Set 9 | linxia
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | mareeba
# Processing Record 35 of Set 9 | balabac
# Processing Record 36 of Set 9 | lasa
# Processing Record 37 of Set 9 | smithers
# Processing Record 38 of Set 9 | kapuskasing
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | digha
# Processing Record 41 of Set 9 | straumen
# Processing Record 42 of Set 9 | devrek
# Processing Record 43 of Set 9 | iralaya
# Processing Record 44 of Set 9 | lishui
# Processing Record 45 of Set 9 | arinos
# Processing Record 46 of Set 9 | sumkino
# Processing Record 47 of Set 9 | coruripe
# Processing Record 48 of Set 9 | creel
# Processing Record 49 of Set 9 | paita
# Processing Record 50 of Set 9 | ayan
# Processing Record 1 of Set 10 | henties bay
# Processing Record 2 of Set 10 | haines junction
# Processing Record 3 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 10 | yerbogachen
# Processing Record 5 of Set 10 | thohoyandou
# Processing Record 6 of Set 10 | salinopolis
# Processing Record 7 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 10 | almaznyy
# Processing Record 9 of Set 10 | lucea
# Processing Record 10 of Set 10 | sept-iles
# Processing Record 11 of Set 10 | horsham
# Processing Record 12 of Set 10 | todos santos
# Processing Record 13 of Set 10 | tuku
# Processing Record 14 of Set 10 | enumclaw
# Processing Record 15 of Set 10 | anadyr
# Processing Record 16 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 10 | tizapan el alto
# Processing Record 18 of Set 10 | emba
# Processing Record 19 of Set 10 | kazerun
# Processing Record 20 of Set 10 | solnechnyy
# Processing Record 21 of Set 10 | himora
# City not found. Skipping...
# Processing Record 22 of Set 10 | gorlice
# Processing Record 23 of Set 10 | chapais
# Processing Record 24 of Set 10 | padang
# Processing Record 25 of Set 10 | belmonte
# Processing Record 26 of Set 10 | ocho rios
# Processing Record 27 of Set 10 | montale
# Processing Record 28 of Set 10 | egvekinot
# Processing Record 29 of Set 10 | te anau
# Processing Record 30 of Set 10 | orzhytsya
# Processing Record 31 of Set 10 | sanmenxia
# Processing Record 32 of Set 10 | itoman
# Processing Record 33 of Set 10 | gandu
# Processing Record 34 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 10 | brae
# Processing Record 37 of Set 10 | batagay-alyta
# Processing Record 38 of Set 10 | fayaoue
# Processing Record 39 of Set 10 | itarema
# Processing Record 40 of Set 10 | rafaela
# Processing Record 41 of Set 10 | ayer itam
# City not found. Skipping...
# Processing Record 42 of Set 10 | omsukchan
# Processing Record 43 of Set 10 | cacapava do sul
# Processing Record 44 of Set 10 | lorengau
# Processing Record 45 of Set 10 | mascote
# Processing Record 46 of Set 10 | sechura
# Processing Record 47 of Set 10 | boende
# Processing Record 48 of Set 10 | cabra
# Processing Record 49 of Set 10 | olafsvik
# Processing Record 50 of Set 10 | yuanping
# Processing Record 1 of Set 11 | chitral
# Processing Record 2 of Set 11 | nuuk
# Processing Record 3 of Set 11 | chicama
# Processing Record 4 of Set 11 | tonantins
# Processing Record 5 of Set 11 | bilma
# Processing Record 6 of Set 11 | imbituba
# Processing Record 7 of Set 11 | sangamner
# Processing Record 8 of Set 11 | rodez
# Processing Record 9 of Set 11 | navsari
# Processing Record 10 of Set 11 | new ulm
# Processing Record 11 of Set 11 | never
# Processing Record 12 of Set 11 | eyl
# Processing Record 13 of Set 11 | gazli
# Processing Record 14 of Set 11 | jian
# Processing Record 15 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 11 | matiguas
# Processing Record 17 of Set 11 | jalu
# Processing Record 18 of Set 11 | half moon bay
# Processing Record 19 of Set 11 | merauke
# Processing Record 20 of Set 11 | beberibe
# Processing Record 21 of Set 11 | escanaba
# Processing Record 22 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 11 | saint-jean-port-joli
# Processing Record 24 of Set 11 | muisne
# Processing Record 25 of Set 11 | jacksonville
# Processing Record 26 of Set 11 | malartic
# Processing Record 27 of Set 11 | harper
# Processing Record 28 of Set 11 | rocha
# Processing Record 29 of Set 11 | sao joao da barra
# Processing Record 30 of Set 11 | gornopravdinsk
# Processing Record 31 of Set 11 | ordynskoye
# Processing Record 32 of Set 11 | touros
# Processing Record 33 of Set 11 | biak
# Processing Record 34 of Set 11 | manakara
# Processing Record 35 of Set 11 | maralal
# Processing Record 36 of Set 11 | aklavik
# Processing Record 37 of Set 11 | oktyabrskoye
# Processing Record 38 of Set 11 | ranau
# Processing Record 39 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 11 | praia da vitoria
# Processing Record 41 of Set 11 | pontianak
# Processing Record 42 of Set 11 | arroyo
# Processing Record 43 of Set 11 | ambanja
# Processing Record 44 of Set 11 | otavi
# Processing Record 45 of Set 11 | flin flon
# Processing Record 46 of Set 11 | klaksvik
# Processing Record 47 of Set 11 | lakes entrance
# Processing Record 48 of Set 11 | salta
# Processing Record 49 of Set 11 | bambous virieux
# Processing Record 50 of Set 11 | arcachon
# Processing Record 1 of Set 12 | lompoc
# Processing Record 2 of Set 12 | santa cruz cabralia
# Processing Record 3 of Set 12 | santiago del estero
# Processing Record 4 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 5 of Set 12 | meulaboh
# Processing Record 6 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 12 | iberia
# Processing Record 9 of Set 12 | juneau
# Processing Record 10 of Set 12 | dali
# Processing Record 11 of Set 12 | kibaya
# Processing Record 12 of Set 12 | port lincoln
# Processing Record 13 of Set 12 | yugo-kamskiy
# Processing Record 14 of Set 12 | fereydun kenar
# Processing Record 15 of Set 12 | zalantun
# Processing Record 16 of Set 12 | seymchan
# Processing Record 17 of Set 12 | bosaso
# Processing Record 18 of Set 12 | kuloy
# Processing Record 19 of Set 12 | arlit
# Processing Record 20 of Set 12 | huarmey
# Processing Record 21 of Set 12 | antofagasta
# Processing Record 22 of Set 12 | mehran
# Processing Record 23 of Set 12 | passo de camaragibe
# Processing Record 24 of Set 12 | basoko
# Processing Record 25 of Set 12 | igrim
# Processing Record 26 of Set 12 | mayor pablo lagerenza
# Processing Record 27 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 12 | laytown
# Processing Record 29 of Set 12 | sorong
# Processing Record 30 of Set 12 | the valley
# Processing Record 31 of Set 12 | mayo
# Processing Record 32 of Set 12 | westport
# Processing Record 33 of Set 12 | nantucket
# Processing Record 34 of Set 12 | zarubino
# Processing Record 35 of Set 12 | mozelos
# Processing Record 36 of Set 12 | skjervoy
# Processing Record 37 of Set 12 | sri aman
# Processing Record 38 of Set 12 | kibala
# Processing Record 39 of Set 12 | tukrah
# Processing Record 40 of Set 12 | laiyang
# Processing Record 41 of Set 12 | goundam
# Processing Record 42 of Set 12 | poya
# Processing Record 43 of Set 12 | quelimane
# Processing Record 44 of Set 12 | fallon
# Processing Record 45 of Set 12 | shinyanga
# Processing Record 46 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 12 | isiro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Atuona      PF  -9.80 -139.03     80.60        73           1
# 1  Oktyabrskiy      RU  54.48   53.47     64.80        87           2
# 2   Bredasdorp      ZA -34.53   20.04     48.20        66           0
# 3      Cilegon      ID  -6.02  106.05     78.80        83          20
# 4   Carutapera      BR  -1.20  -46.02     77.54        89          36
# 5     Hermanus      ZA -34.42   19.23     55.99        72           1
# 6    Zhanaozen      KZ  43.30   52.80     80.37        36           0
# 7         Tual      ID  -5.67  132.75     79.07        81          57
# 8    Carnarvon      AU -24.87  113.63     57.20        93          27
# 9      Mataura      NZ -46.19  168.86     39.00        83          90
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0       22.46           clear sky            0.0              0
# 1        5.55           clear sky            0.0              0
# 2        2.24           clear sky            0.0              0
# 3        4.70                haze            0.0              0
# 4        5.68    scattered clouds            0.0              0
# 5       20.00           clear sky            0.0              0
# 6        3.89           clear sky            0.0              0
# 7       22.91       broken clouds            0.0              0
# 8        8.05    scattered clouds            0.0              0
# 9        3.00     overcast clouds            0.0              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
