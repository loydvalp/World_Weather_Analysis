# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random 
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 16.9 µs ± 1.92 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500. 
# %timeit latitudes(1500)
# Out:
# 2.66 ms ± 229 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=84bf783b0426ae0eabcc200e14cbdb41

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        pass
    
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0 
        pass
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")
# Convert the array of dictionaries to a Pandas DataFrame.
# Out:
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | vieques
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | bjornevatn
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | jujuy
# City not found. Skipping...
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | guarapari
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | imeni poliny osipenko
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | shimoda
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | rio gallegos
# Processing Record 25 of Set 1 | oistins
# Processing Record 26 of Set 1 | seoul
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | warrnambool
# Processing Record 30 of Set 1 | saint-georges
# Processing Record 31 of Set 1 | grindavik
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | waingapu
# Processing Record 36 of Set 1 | rabo de peixe
# Processing Record 37 of Set 1 | haines junction
# Processing Record 38 of Set 1 | zhigansk
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | urengoy
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | merauke
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | poum
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | neryungri
# Processing Record 48 of Set 1 | sakakah
# Processing Record 49 of Set 1 | ajaccio
# Processing Record 50 of Set 1 | santa helena
# Processing Record 1 of Set 2 | vestmannaeyjar
# Processing Record 2 of Set 2 | oktyabrskiy
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | russell
# Processing Record 7 of Set 2 | marrakesh
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | omboue
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | baruun-urt
# Processing Record 14 of Set 2 | tahoua
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | isiro
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | ewa beach
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | quelimane
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | mucurapo
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | lapy
# Processing Record 29 of Set 2 | lahij
# Processing Record 30 of Set 2 | kaeo
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | goundam
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | muravlenko
# Processing Record 35 of Set 2 | salekhard
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | coquimbo
# Processing Record 38 of Set 2 | bairiki
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | fayaoue
# Processing Record 41 of Set 2 | klaksvik
# Processing Record 42 of Set 2 | soligalich
# Processing Record 43 of Set 2 | sept-iles
# Processing Record 44 of Set 2 | amga
# Processing Record 45 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record 46 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 2 | te anau
# Processing Record 48 of Set 2 | bima
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | nalut
# Processing Record 2 of Set 3 | busselton
# Processing Record 3 of Set 3 | mananjary
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | jabinyanah
# Processing Record 6 of Set 3 | charters towers
# Processing Record 7 of Set 3 | andenes
# Processing Record 8 of Set 3 | biala podlaska
# Processing Record 9 of Set 3 | havre-saint-pierre
# Processing Record 10 of Set 3 | mao
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | tianpeng
# Processing Record 14 of Set 3 | dubai
# Processing Record 15 of Set 3 | cravo norte
# Processing Record 16 of Set 3 | marsa matruh
# Processing Record 17 of Set 3 | enid
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | adrar
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | portland
# Processing Record 22 of Set 3 | la ronge
# Processing Record 23 of Set 3 | chom bung
# City not found. Skipping...
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | kasongo-lunda
# Processing Record 27 of Set 3 | ambon
# Processing Record 28 of Set 3 | mount isa
# Processing Record 29 of Set 3 | yumen
# Processing Record 30 of Set 3 | saqqez
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | igarka
# Processing Record 35 of Set 3 | salo
# Processing Record 36 of Set 3 | kloulklubed
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | tema
# Processing Record 39 of Set 3 | anito
# Processing Record 40 of Set 3 | ostrovnoy
# Processing Record 41 of Set 3 | idaho falls
# Processing Record 42 of Set 3 | teya
# Processing Record 43 of Set 3 | simao
# Processing Record 44 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 3 | atuona
# Processing Record 46 of Set 3 | arawa
# Processing Record 47 of Set 3 | ribeira grande
# Processing Record 48 of Set 3 | constantine
# Processing Record 49 of Set 3 | yeniseysk
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | calama
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | buzmeyin
# Processing Record 6 of Set 4 | narasaraopet
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | kirkwall
# Processing Record 9 of Set 4 | port hardy
# Processing Record 10 of Set 4 | okha
# Processing Record 11 of Set 4 | odessa
# Processing Record 12 of Set 4 | sigulda
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | srednekolymsk
# Processing Record 15 of Set 4 | noumea
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | middle island
# Processing Record 20 of Set 4 | jorpeland
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | kanchipuram
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | sovetskaya gavan
# Processing Record 25 of Set 4 | naryan-mar
# Processing Record 26 of Set 4 | chokurdakh
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | vila do maio
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | katangli
# Processing Record 31 of Set 4 | danielskuil
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 4 | muli
# Processing Record 35 of Set 4 | loandjili
# Processing Record 36 of Set 4 | asau
# Processing Record 37 of Set 4 | flinders
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | piacabucu
# Processing Record 40 of Set 4 | port hedland
# Processing Record 41 of Set 4 | hukuntsi
# Processing Record 42 of Set 4 | wapi pathum
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | pochutla
# Processing Record 45 of Set 4 | nacogdoches
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | mabaruma
# Processing Record 49 of Set 4 | dawlatabad
# Processing Record 50 of Set 4 | pingliang
# Processing Record 1 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 2 of Set 5 | nikolskoye
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | dikson
# Processing Record 6 of Set 5 | bam
# Processing Record 7 of Set 5 | sorland
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | butaritari
# Processing Record 11 of Set 5 | erzincan
# Processing Record 12 of Set 5 | ngunguru
# Processing Record 13 of Set 5 | castro
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | kruisfontein
# Processing Record 16 of Set 5 | atar
# Processing Record 17 of Set 5 | van
# Processing Record 18 of Set 5 | touros
# Processing Record 19 of Set 5 | greenland
# Processing Record 20 of Set 5 | mujiayingzi
# Processing Record 21 of Set 5 | caravelas
# Processing Record 22 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 5 | carrick-on-suir
# Processing Record 24 of Set 5 | lazaro cardenas
# Processing Record 25 of Set 5 | naze
# Processing Record 26 of Set 5 | maningrida
# Processing Record 27 of Set 5 | pontiac
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | deputatskiy
# Processing Record 30 of Set 5 | aden
# Processing Record 31 of Set 5 | fenoarivo
# Processing Record 32 of Set 5 | sinnamary
# Processing Record 33 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 5 | kashi
# Processing Record 35 of Set 5 | marsh harbour
# Processing Record 36 of Set 5 | teguldet
# Processing Record 37 of Set 5 | leon
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | honningsvag
# Processing Record 40 of Set 5 | misratah
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | wageningen
# Processing Record 43 of Set 5 | arona
# Processing Record 44 of Set 5 | taoudenni
# Processing Record 45 of Set 5 | yulara
# Processing Record 46 of Set 5 | faya
# Processing Record 47 of Set 5 | saint-orens-de-gameville
# Processing Record 48 of Set 5 | erenhot
# Processing Record 49 of Set 5 | kielce
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | queimadas
# Processing Record 2 of Set 6 | jeremie
# Processing Record 3 of Set 6 | comodoro rivadavia
# Processing Record 4 of Set 6 | bourail
# Processing Record 5 of Set 6 | vorchdorf
# Processing Record 6 of Set 6 | ust-maya
# Processing Record 7 of Set 6 | victoria
# Processing Record 8 of Set 6 | radhanpur
# Processing Record 9 of Set 6 | tabou
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | kushima
# Processing Record 12 of Set 6 | gazli
# Processing Record 13 of Set 6 | provideniya
# Processing Record 14 of Set 6 | shizilu
# Processing Record 15 of Set 6 | katsuura
# Processing Record 16 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 6 | brae
# Processing Record 18 of Set 6 | matiri
# Processing Record 19 of Set 6 | lamar
# Processing Record 20 of Set 6 | torbay
# Processing Record 21 of Set 6 | galion
# Processing Record 22 of Set 6 | ayan
# Processing Record 23 of Set 6 | bathsheba
# Processing Record 24 of Set 6 | ixtapa
# Processing Record 25 of Set 6 | luderitz
# Processing Record 26 of Set 6 | olafsvik
# Processing Record 27 of Set 6 | ulaangom
# Processing Record 28 of Set 6 | ponazyrevo
# Processing Record 29 of Set 6 | jertih
# Processing Record 30 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 6 | coro
# Processing Record 32 of Set 6 | quatre cocos
# Processing Record 33 of Set 6 | barra patuca
# Processing Record 34 of Set 6 | hami
# Processing Record 35 of Set 6 | vygonichi
# Processing Record 36 of Set 6 | sisimiut
# Processing Record 37 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 6 | sao geraldo do araguaia
# Processing Record 39 of Set 6 | maragogi
# Processing Record 40 of Set 6 | kununurra
# Processing Record 41 of Set 6 | ponta delgada
# Processing Record 42 of Set 6 | alpena
# Processing Record 43 of Set 6 | severo-kurilsk
# Processing Record 44 of Set 6 | port elizabeth
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 6 | port blair
# Processing Record 47 of Set 6 | ilhabela
# Processing Record 48 of Set 6 | alugan
# Processing Record 49 of Set 6 | kahului
# Processing Record 50 of Set 6 | plettenberg bay
# Processing Record 1 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | vanavara
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | tommot
# Processing Record 5 of Set 7 | piranhas
# Processing Record 6 of Set 7 | bahir dar
# Processing Record 7 of Set 7 | constitucion
# Processing Record 8 of Set 7 | kamenka
# Processing Record 9 of Set 7 | bowen
# Processing Record 10 of Set 7 | victor harbor
# Processing Record 11 of Set 7 | meulaboh
# Processing Record 12 of Set 7 | churapcha
# Processing Record 13 of Set 7 | ponta do sol
# Processing Record 14 of Set 7 | tilichiki
# Processing Record 15 of Set 7 | nova olimpia
# Processing Record 16 of Set 7 | bulgan
# Processing Record 17 of Set 7 | bonavista
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | manokwari
# Processing Record 20 of Set 7 | necochea
# Processing Record 21 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 7 | hailey
# Processing Record 23 of Set 7 | leh
# Processing Record 24 of Set 7 | san javier
# Processing Record 25 of Set 7 | pangnirtung
# Processing Record 26 of Set 7 | kurchum
# Processing Record 27 of Set 7 | cilegon
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | thaba nchu
# Processing Record 30 of Set 7 | chapais
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | hofn
# Processing Record 33 of Set 7 | jand
# Processing Record 34 of Set 7 | dhidhdhoo
# Processing Record 35 of Set 7 | jumla
# Processing Record 36 of Set 7 | san carlos de bariloche
# Processing Record 37 of Set 7 | great yarmouth
# Processing Record 38 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 7 | motygino
# Processing Record 40 of Set 7 | rengasdengklok
# Processing Record 41 of Set 7 | aswan
# Processing Record 42 of Set 7 | safranbolu
# Processing Record 43 of Set 7 | markova
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | kokopo
# Processing Record 46 of Set 7 | el alto
# Processing Record 47 of Set 7 | ternate
# Processing Record 48 of Set 7 | lar
# Processing Record 49 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 7 | vao
# Processing Record 1 of Set 8 | saint-nazaire
# Processing Record 2 of Set 8 | cairns
# Processing Record 3 of Set 8 | pasighat
# Processing Record 4 of Set 8 | almaznyy
# Processing Record 5 of Set 8 | nome
# Processing Record 6 of Set 8 | la union
# Processing Record 7 of Set 8 | copiapo
# Processing Record 8 of Set 8 | bojnurd
# Processing Record 9 of Set 8 | luganville
# Processing Record 10 of Set 8 | kut chap
# Processing Record 11 of Set 8 | khasan
# Processing Record 12 of Set 8 | san quintin
# Processing Record 13 of Set 8 | banjar
# Processing Record 14 of Set 8 | baymak
# Processing Record 15 of Set 8 | honiara
# Processing Record 16 of Set 8 | dunedin
# Processing Record 17 of Set 8 | zhanaozen
# Processing Record 18 of Set 8 | linhares
# Processing Record 19 of Set 8 | bubaque
# Processing Record 20 of Set 8 | ndele
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | hammerfest
# Processing Record 23 of Set 8 | san juan
# Processing Record 24 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 8 | general roca
# Processing Record 26 of Set 8 | manggar
# Processing Record 27 of Set 8 | margate
# Processing Record 28 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 8 | limon
# Processing Record 30 of Set 8 | gizo
# Processing Record 31 of Set 8 | zheleznodorozhnyy
# Processing Record 32 of Set 8 | kefamenanu
# Processing Record 33 of Set 8 | kismayo
# Processing Record 34 of Set 8 | souris
# Processing Record 35 of Set 8 | thinadhoo
# Processing Record 36 of Set 8 | cherskiy
# Processing Record 37 of Set 8 | katherine
# Processing Record 38 of Set 8 | tumpat
# Processing Record 39 of Set 8 | avera
# Processing Record 40 of Set 8 | bushenyi
# Processing Record 41 of Set 8 | liverpool
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | rimbey
# Processing Record 44 of Set 8 | geraldton
# Processing Record 45 of Set 8 | hohhot
# Processing Record 46 of Set 8 | tual
# Processing Record 47 of Set 8 | bone
# Processing Record 48 of Set 8 | calvia
# Processing Record 49 of Set 8 | namatanai
# Processing Record 50 of Set 8 | hovd
# Processing Record 1 of Set 9 | rochegda
# Processing Record 2 of Set 9 | santa fe
# Processing Record 3 of Set 9 | farafenni
# Processing Record 4 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 5 of Set 9 | znamenskoye
# Processing Record 6 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 9 | udachnyy
# Processing Record 8 of Set 9 | ambilobe
# Processing Record 9 of Set 9 | faanui
# Processing Record 10 of Set 9 | denpasar
# Processing Record 11 of Set 9 | san patricio
# Processing Record 12 of Set 9 | fairbanks
# Processing Record 13 of Set 9 | celestun
# Processing Record 14 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 15 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 9 | chudovo
# Processing Record 17 of Set 9 | anderson
# Processing Record 18 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 9 | araceli
# Processing Record 20 of Set 9 | nanortalik
# Processing Record 21 of Set 9 | demyansk
# Processing Record 22 of Set 9 | lufilufi
# Processing Record 23 of Set 9 | lorengau
# Processing Record 24 of Set 9 | mathbaria
# Processing Record 25 of Set 9 | lasa
# Processing Record 26 of Set 9 | progreso
# Processing Record 27 of Set 9 | kieta
# Processing Record 28 of Set 9 | eureka
# Processing Record 29 of Set 9 | basco
# Processing Record 30 of Set 9 | padang
# Processing Record 31 of Set 9 | houma
# Processing Record 32 of Set 9 | areosa
# Processing Record 33 of Set 9 | mulgund
# Processing Record 34 of Set 9 | duki
# Processing Record 35 of Set 9 | da lat
# Processing Record 36 of Set 9 | la gaulette
# City not found. Skipping...
# Processing Record 37 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 9 | karratha
# Processing Record 39 of Set 9 | biak
# Processing Record 40 of Set 9 | nara
# Processing Record 41 of Set 9 | college
# Processing Record 42 of Set 9 | san cristobal
# Processing Record 43 of Set 9 | zigong
# Processing Record 44 of Set 9 | vila
# Processing Record 45 of Set 9 | oranjemund
# Processing Record 46 of Set 9 | rovaniemi
# Processing Record 47 of Set 9 | inuvik
# Processing Record 48 of Set 9 | beyneu
# Processing Record 49 of Set 9 | takaka
# Processing Record 50 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 1 of Set 10 | santa isabel do rio negro
# Processing Record 2 of Set 10 | grand gaube
# Processing Record 3 of Set 10 | anadyr
# Processing Record 4 of Set 10 | guerrero negro
# Processing Record 5 of Set 10 | kyren
# Processing Record 6 of Set 10 | perth
# Processing Record 7 of Set 10 | grand-santi
# Processing Record 8 of Set 10 | tiarei
# Processing Record 9 of Set 10 | gelemso
# Processing Record 10 of Set 10 | pran buri
# Processing Record 11 of Set 10 | fukue
# Processing Record 12 of Set 10 | ugoofaaru
# Processing Record 13 of Set 10 | berlevag
# Processing Record 14 of Set 10 | marzuq
# Processing Record 15 of Set 10 | devarkonda
# Processing Record 16 of Set 10 | saravan
# Processing Record 17 of Set 10 | lompoc
# Processing Record 18 of Set 10 | makasar
# Processing Record 19 of Set 10 | borba
# Processing Record 20 of Set 10 | yar-sale
# Processing Record 21 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 10 | iqaluit
# Processing Record 23 of Set 10 | hasaki
# Processing Record 24 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 25 of Set 10 | axim
# Processing Record 26 of Set 10 | nacala
# Processing Record 27 of Set 10 | shingu
# Processing Record 28 of Set 10 | luba
# Processing Record 29 of Set 10 | cordoba
# Processing Record 30 of Set 10 | yatou
# Processing Record 31 of Set 10 | banda aceh
# Processing Record 32 of Set 10 | cockburn town
# Processing Record 33 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 34 of Set 10 | ekhabi
# Processing Record 35 of Set 10 | kirksville
# Processing Record 36 of Set 10 | mitzic
# Processing Record 37 of Set 10 | turukhansk
# Processing Record 38 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 39 of Set 10 | dongsheng
# Processing Record 40 of Set 10 | arlit
# Processing Record 41 of Set 10 | oum hadjer
# Processing Record 42 of Set 10 | kalakamati
# Processing Record 43 of Set 10 | masallatah
# Processing Record 44 of Set 10 | sturgis
# Processing Record 45 of Set 10 | port augusta
# Processing Record 46 of Set 10 | chambas
# Processing Record 47 of Set 10 | port keats
# Processing Record 48 of Set 10 | rosetta
# Processing Record 49 of Set 10 | saint-pierre
# Processing Record 50 of Set 10 | yeppoon
# Processing Record 1 of Set 11 | batemans bay
# Processing Record 2 of Set 11 | corinth
# Processing Record 3 of Set 11 | zherdevka
# Processing Record 4 of Set 11 | fomboni
# Processing Record 5 of Set 11 | pedasi
# Processing Record 6 of Set 11 | mishkino
# Processing Record 7 of Set 11 | saint-joseph
# Processing Record 8 of Set 11 | vanimo
# Processing Record 9 of Set 11 | bilma
# Processing Record 10 of Set 11 | rio grande
# Processing Record 11 of Set 11 | kannad
# Processing Record 12 of Set 11 | ahipara
# Processing Record 13 of Set 11 | sungaipenuh
# Processing Record 14 of Set 11 | lagoa
# Processing Record 15 of Set 11 | ormara
# Processing Record 16 of Set 11 | paita
# Processing Record 17 of Set 11 | amposta
# Processing Record 18 of Set 11 | taranagar
# Processing Record 19 of Set 11 | dingtao
# Processing Record 20 of Set 11 | virginia beach
# Processing Record 21 of Set 11 | pacific grove
# Processing Record 22 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 11 | shelburne
# Processing Record 24 of Set 11 | galveston
# Processing Record 25 of Set 11 | pergamino
# Processing Record 26 of Set 11 | kondopoga
# Processing Record 27 of Set 11 | rosetown
# Processing Record 28 of Set 11 | jalu
# Processing Record 29 of Set 11 | fort nelson
# Processing Record 30 of Set 11 | irtyshskiy
# Processing Record 31 of Set 11 | tazovskiy
# Processing Record 32 of Set 11 | cayenne
# Processing Record 33 of Set 11 | alta floresta
# Processing Record 34 of Set 11 | san policarpo
# Processing Record 35 of Set 11 | santa rosa
# Processing Record 36 of Set 11 | gondanglegi
# Processing Record 37 of Set 11 | teknaf
# Processing Record 38 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 11 | almeria
# Processing Record 40 of Set 11 | atascadero
# Processing Record 41 of Set 11 | sangar
# Processing Record 42 of Set 11 | pangoa
# Processing Record 43 of Set 11 | tessalit
# Processing Record 44 of Set 11 | burica
# City not found. Skipping...
# Processing Record 45 of Set 11 | bac lieu
# Processing Record 46 of Set 11 | calamar
# Processing Record 47 of Set 11 | puerto narino
# Processing Record 48 of Set 11 | barhi
# Processing Record 49 of Set 11 | golden
# Processing Record 50 of Set 11 | manhuacu
# Processing Record 1 of Set 12 | panjakent
# Processing Record 2 of Set 12 | araouane
# Processing Record 3 of Set 12 | camana
# Processing Record 4 of Set 12 | wrzesnia
# Processing Record 5 of Set 12 | hirara
# Processing Record 6 of Set 12 | funadhoo
# Processing Record 7 of Set 12 | rancho palos verdes
# Processing Record 8 of Set 12 | hobyo
# Processing Record 9 of Set 12 | puerto carreno
# Processing Record 10 of Set 12 | ust-nera
# Processing Record 11 of Set 12 | multai
# Processing Record 12 of Set 12 | evensk
# Processing Record 13 of Set 12 | shagamu
# Processing Record 14 of Set 12 | beidao
# Processing Record 15 of Set 12 | capitao poco
# Processing Record 16 of Set 12 | serebryansk
# Processing Record 17 of Set 12 | santa cruz
# Processing Record 18 of Set 12 | yashan
# Processing Record 19 of Set 12 | islamnagar
# Processing Record 20 of Set 12 | boyolangu
# Processing Record 21 of Set 12 | baragua
# Processing Record 22 of Set 12 | do rud
# City not found. Skipping...
# Processing Record 23 of Set 12 | port macquarie
# Processing Record 24 of Set 12 | aranos
# Processing Record 25 of Set 12 | chicama
# Processing Record 26 of Set 12 | abiy adi
# City not found. Skipping...
# Processing Record 27 of Set 12 | acarau
# Processing Record 28 of Set 12 | riachao das neves
# Processing Record 29 of Set 12 | akyab
# Processing Record 30 of Set 12 | aksarka
# Processing Record 31 of Set 12 | mehamn
# Processing Record 32 of Set 12 | saint paul
# Processing Record 33 of Set 12 | alice springs
# Processing Record 34 of Set 12 | binga
# Processing Record 35 of Set 12 | bosaso
# Processing Record 36 of Set 12 | bossier city
# Processing Record 37 of Set 12 | warri
# Processing Record 38 of Set 12 | borogontsy
# Processing Record 39 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 12 | xiaoweizhai
# Processing Record 42 of Set 12 | sokna
# Processing Record 43 of Set 12 | edd
# Processing Record 44 of Set 12 | maniitsoq
# Processing Record 45 of Set 12 | kalmunai
# Processing Record 46 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 12 | lumsden
# Processing Record 48 of Set 12 | kemijarvi
# Processing Record 49 of Set 12 | la seyne-sur-mer
# Processing Record 50 of Set 12 | beringovskiy
# Processing Record 1 of Set 13 | sansai
# City not found. Skipping...
# Processing Record 2 of Set 13 | caditaan
# Processing Record 3 of Set 13 | barao de melgaco
# Processing Record 4 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 13 | tavda
# Processing Record 8 of Set 13 | nizhniy tsasuchey
# Processing Record 9 of Set 13 | sibu
# Processing Record 10 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 13 | chute-aux-outardes
# Processing Record 13 of Set 13 | gavle
# Processing Record 14 of Set 13 | hamilton
# Processing Record 15 of Set 13 | broken hill
# Processing Record 16 of Set 13 | banes
# Processing Record 17 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 18 of Set 13 | sinop
# Processing Record 19 of Set 13 | maple creek
# Processing Record 20 of Set 13 | sioux lookout
# Processing Record 21 of Set 13 | nantucket
# Processing Record 22 of Set 13 | louga
# Processing Record 23 of Set 13 | glenwood springs
# Processing Record 24 of Set 13 | natal
# Processing Record 25 of Set 13 | puerto rico
# Processing Record 26 of Set 13 | iracoubo
# Processing Record 27 of Set 13 | darhan
# Processing Record 28 of Set 13 | duz
# City not found. Skipping...
# Processing Record 29 of Set 13 | bukama
# Processing Record 30 of Set 13 | saint-francois
# Processing Record 31 of Set 13 | bokhan
# Processing Record 32 of Set 13 | karaul
# City not found. Skipping...

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Georgetown      MY   5.41  100.34     82.40        94          40
# 1  Bredasdorp      ZA -34.53   20.04     48.20        81          58
# 2  Sao Filipe      CV  14.90  -24.50     74.50        85           2
# 3      Albany      US  42.60  -73.97     78.01        90         100
# 4     Rikitea      PF -23.12 -134.97     67.32        70          72
# 5   Tuatapere      NZ -46.13  167.68     51.35        71          15
# 6       Vaini      TO -21.20 -175.20     77.00        69          20
# 7     Vieques      PR  18.43  -65.83     84.20        83          40
# 8     Ushuaia      AR -54.80  -68.30     33.80        74          20
# 9   Upernavik      GL  72.79  -56.15     42.30        84         100
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        3.36        thunderstorm           0.00              0
# 1       12.75       broken clouds           0.00              0
# 2        7.83           clear sky           0.00              0
# 3        6.73       moderate rain           1.04              0
# 4       18.41       broken clouds           0.00              0
# 5        7.92          few clouds           0.00              0
# 6       11.41          few clouds           0.00              0
# 7       10.29    scattered clouds           0.00              0
# 8        4.70          few clouds           0.00              0
# 9       16.37     overcast clouds           0.00              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
